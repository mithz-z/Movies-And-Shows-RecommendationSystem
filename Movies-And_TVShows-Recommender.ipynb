# %%
# Importing Libraries
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
# Importing the dataset
df = pd.read_csv('netflix_titles.csv', header=0)
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...

# %% [markdown]
# # Data Preprocessing

# %%
df['director'].isnull().sum()
# Out:
# 2634

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_non_null = df.fillna(' ')
df_non_null
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                        United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
# Taking the necessary columns as features for machine learing
df_cols = df_non_null[['show_id','type', 'director', 'cast', 'country', 'listed_in']]
df_cols
# Out:
#      show_id     type         director  \
# 0         s1    Movie  Kirsten Johnson
# 1         s2  TV Show
# 2         s3  TV Show  Julien Leclercq
# 3         s4  TV Show
# 4         s5  TV Show
# ...      ...      ...              ...
# 8802   s8803    Movie    David Fincher
# 8803   s8804  TV Show
# 8804   s8805    Movie  Ruben Fleischer
# 8805   s8806    Movie     Peter Hewitt
# 8806   s8807    Movie      Mozez Singh
#
#                                                    cast        country  \
# 0                                                        United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
# [8807 rows x 6 columns]

# %%
# This function converts all upercases into lowercases and removes the space in between words
for i in df_cols:
    df_cols[i] = df_cols[i].apply(lambda x: x.replace(' ',''))
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_13288\3790776143.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cols[i] = df_cols[i].apply(lambda x: x.replace(' ',''))

# %%
df_cols
# Out:
#      show_id    type        director  \
# 0         s1   Movie  KirstenJohnson
# 1         s2  TVShow
# 2         s3  TVShow  JulienLeclercq
# 3         s4  TVShow
# 4         s5  TVShow
# ...      ...     ...             ...
# 8802   s8803   Movie    DavidFincher
# 8803   s8804  TVShow
# 8804   s8805   Movie  RubenFleischer
# 8805   s8806   Movie     PeterHewitt
# 8806   s8807   Movie      MozezSingh
#
#                                                    cast       country  \
# 0                                                        UnitedStates
# 1     AmaQamata,KhosiNgema,GailMabalane,ThabangMolab...   SouthAfrica
# 2     SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkka...
# 3
# 4     MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ahs...         India
# ...                                                 ...           ...
# 8802  MarkRuffalo,JakeGyllenhaal,RobertDowneyJr.,Ant...  UnitedStates
# 8803
# 8804  JesseEisenberg,WoodyHarrelson,EmmaStone,Abigai...  UnitedStates
# 8805  TimAllen,CourteneyCox,ChevyChase,KateMara,Ryan...  UnitedStates
# 8806  VickyKaushal,Sarah-JaneDias,RaaghavChanana,Man...         India
#
#                                               listed_in
# 0                                         Documentaries
# 1             InternationalTVShows,TVDramas,TVMysteries
# 2     CrimeTVShows,InternationalTVShows,TVAction&Adv...
# 3                                  Docuseries,RealityTV
# 4       InternationalTVShows,RomanticTVShows,TVComedies
# ...                                                 ...
# 8802                        CultMovies,Dramas,Thrillers
# 8803                   Kids'TV,KoreanTVShows,TVComedies
# 8804                              Comedies,HorrorMovies
# 8805                     Children&FamilyMovies,Comedies
# 8806          Dramas,InternationalMovies,Music&Musicals
#
# [8807 rows x 6 columns]

# %%
# Creating a tags columns with all the keywords
df_cols['tags'] = df_cols['type'] + ' ' + df_cols['director'] + ' ' + df_cols['cast'] + ' ' + df_cols['country'] + ' ' + df_cols['listed_in'] + ' ' + df_non_null['rating'] + ' ' + df_non_null['description']
df_cols['tags']
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_13288\546312248.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cols['tags'] = df_cols['type'] + ' ' + df_cols['director'] + ' ' + df_cols['cast'] + ' ' + df_cols['country'] + ' ' + df_cols['listed_in'] + ' ' + df_non_null['rating'] + ' ' + df_non_null['description']
# 0       Movie KirstenJohnson  UnitedStates Documentari...
# 1       TVShow  AmaQamata,KhosiNgema,GailMabalane,Thab...
# 2       TVShow JulienLeclercq SamiBouajila,TracyGotoas...
# 3       TVShow    Docuseries,RealityTV TV-MA Feuds, fl...
# 4       TVShow  MayurMore,JitendraKumar,RanjanRaj,Alam...
#                               ...
# 8802    Movie DavidFincher MarkRuffalo,JakeGyllenhaal,...
# 8803    TVShow    Kids'TV,KoreanTVShows,TVComedies TV-...
# 8804    Movie RubenFleischer JesseEisenberg,WoodyHarre...
# 8805    Movie PeterHewitt TimAllen,CourteneyCox,ChevyC...
# 8806    Movie MozezSingh VickyKaushal,Sarah-JaneDias,R...
# Name: tags, Length: 8807, dtype: object

# %%
df_cols = df_cols.merge(df_non_null[['show_id', 'title']])
df_cols
# Out:
#      show_id    type        director  \
# 0         s1   Movie  KirstenJohnson
# 1         s2  TVShow
# 2         s3  TVShow  JulienLeclercq
# 3         s4  TVShow
# 4         s5  TVShow
# ...      ...     ...             ...
# 8802   s8803   Movie    DavidFincher
# 8803   s8804  TVShow
# 8804   s8805   Movie  RubenFleischer
# 8805   s8806   Movie     PeterHewitt
# 8806   s8807   Movie      MozezSingh
#
#                                                    cast       country  \
# 0                                                        UnitedStates
# 1     AmaQamata,KhosiNgema,GailMabalane,ThabangMolab...   SouthAfrica
# 2     SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkka...
# 3
# 4     MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ahs...         India
# ...                                                 ...           ...
# 8802  MarkRuffalo,JakeGyllenhaal,RobertDowneyJr.,Ant...  UnitedStates
# 8803
# 8804  JesseEisenberg,WoodyHarrelson,EmmaStone,Abigai...  UnitedStates
# 8805  TimAllen,CourteneyCox,ChevyChase,KateMara,Ryan...  UnitedStates
# 8806  VickyKaushal,Sarah-JaneDias,RaaghavChanana,Man...         India
#
#                                               listed_in  \
# 0                                         Documentaries
# 1             InternationalTVShows,TVDramas,TVMysteries
# 2     CrimeTVShows,InternationalTVShows,TVAction&Adv...
# 3                                  Docuseries,RealityTV
# 4       InternationalTVShows,RomanticTVShows,TVComedies
# ...                                                 ...
# 8802                        CultMovies,Dramas,Thrillers
# 8803                   Kids'TV,KoreanTVShows,TVComedies
# 8804                              Comedies,HorrorMovies
# 8805                     Children&FamilyMovies,Comedies
# 8806          Dramas,InternationalMovies,Music&Musicals
#
#                                                    tags                  title
# 0     Movie KirstenJohnson  UnitedStates Documentari...   Dick Johnson Is Dead
# 1     TVShow  AmaQamata,KhosiNgema,GailMabalane,Thab...          Blood & Water
# 2     TVShow JulienLeclercq SamiBouajila,TracyGotoas...              Ganglands
# 3     TVShow    Docuseries,RealityTV TV-MA Feuds, fl...  Jailbirds New Orleans
# 4     TVShow  MayurMore,JitendraKumar,RanjanRaj,Alam...           Kota Factory
# ...                                                 ...                    ...
# 8802  Movie DavidFincher MarkRuffalo,JakeGyllenhaal,...                 Zodiac
# 8803  TVShow    Kids'TV,KoreanTVShows,TVComedies TV-...            Zombie Dumb
# 8804  Movie RubenFleischer JesseEisenberg,WoodyHarre...             Zombieland
# 8805  Movie PeterHewitt TimAllen,CourteneyCox,ChevyC...                   Zoom
# 8806  Movie MozezSingh VickyKaushal,Sarah-JaneDias,R...                 Zubaan
#
# [8807 rows x 8 columns]

# %%
# Converting all the tags to lower case
df_cols['tags'] = df_cols['tags'].apply(lambda x: str.lower(x))
df_cols
# Out:
#      show_id    type        director  \
# 0         s1   Movie  KirstenJohnson
# 1         s2  TVShow
# 2         s3  TVShow  JulienLeclercq
# 3         s4  TVShow
# 4         s5  TVShow
# ...      ...     ...             ...
# 8802   s8803   Movie    DavidFincher
# 8803   s8804  TVShow
# 8804   s8805   Movie  RubenFleischer
# 8805   s8806   Movie     PeterHewitt
# 8806   s8807   Movie      MozezSingh
#
#                                                    cast       country  \
# 0                                                        UnitedStates
# 1     AmaQamata,KhosiNgema,GailMabalane,ThabangMolab...   SouthAfrica
# 2     SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkka...
# 3
# 4     MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ahs...         India
# ...                                                 ...           ...
# 8802  MarkRuffalo,JakeGyllenhaal,RobertDowneyJr.,Ant...  UnitedStates
# 8803
# 8804  JesseEisenberg,WoodyHarrelson,EmmaStone,Abigai...  UnitedStates
# 8805  TimAllen,CourteneyCox,ChevyChase,KateMara,Ryan...  UnitedStates
# 8806  VickyKaushal,Sarah-JaneDias,RaaghavChanana,Man...         India
#
#                                               listed_in  \
# 0                                         Documentaries
# 1             InternationalTVShows,TVDramas,TVMysteries
# 2     CrimeTVShows,InternationalTVShows,TVAction&Adv...
# 3                                  Docuseries,RealityTV
# 4       InternationalTVShows,RomanticTVShows,TVComedies
# ...                                                 ...
# 8802                        CultMovies,Dramas,Thrillers
# 8803                   Kids'TV,KoreanTVShows,TVComedies
# 8804                              Comedies,HorrorMovies
# 8805                     Children&FamilyMovies,Comedies
# 8806          Dramas,InternationalMovies,Music&Musicals
#
#                                                    tags                  title
# 0     movie kirstenjohnson  unitedstates documentari...   Dick Johnson Is Dead
# 1     tvshow  amaqamata,khosingema,gailmabalane,thab...          Blood & Water
# 2     tvshow julienleclercq samibouajila,tracygotoas...              Ganglands
# 3     tvshow    docuseries,realitytv tv-ma feuds, fl...  Jailbirds New Orleans
# 4     tvshow  mayurmore,jitendrakumar,ranjanraj,alam...           Kota Factory
# ...                                                 ...                    ...
# 8802  movie davidfincher markruffalo,jakegyllenhaal,...                 Zodiac
# 8803  tvshow    kids'tv,koreantvshows,tvcomedies tv-...            Zombie Dumb
# 8804  movie rubenfleischer jesseeisenberg,woodyharre...             Zombieland
# 8805  movie peterhewitt timallen,courteneycox,chevyc...                   Zoom
# 8806  movie mozezsingh vickykaushal,sarah-janedias,r...                 Zubaan
#
# [8807 rows x 8 columns]

# %%
# Final dataset
df_clean = df_cols[['title', 'tags']]
df_clean
# Out:
#                       title                                               tags
# 0      Dick Johnson Is Dead  movie kirstenjohnson  unitedstates documentari...
# 1             Blood & Water  tvshow  amaqamata,khosingema,gailmabalane,thab...
# 2                 Ganglands  tvshow julienleclercq samibouajila,tracygotoas...
# 3     Jailbirds New Orleans  tvshow    docuseries,realitytv tv-ma feuds, fl...
# 4              Kota Factory  tvshow  mayurmore,jitendrakumar,ranjanraj,alam...
# ...                     ...                                                ...
# 8802                 Zodiac  movie davidfincher markruffalo,jakegyllenhaal,...
# 8803            Zombie Dumb  tvshow    kids'tv,koreantvshows,tvcomedies tv-...
# 8804             Zombieland  movie rubenfleischer jesseeisenberg,woodyharre...
# 8805                   Zoom  movie peterhewitt timallen,courteneycox,chevyc...
# 8806                 Zubaan  movie mozezsingh vickykaushal,sarah-janedias,r...
#
# [8807 rows x 2 columns]

# %%
# Applying stemming on tags
ps = PorterStemmer()
def stem(text):
    y = []
    for i in text.split(): 
        y.append(ps.stem(i))
    return ' '.join(y)

# %%
df_clean['tags'] = df_clean['tags'].apply(stem)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_13288\1305756591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['tags'] = df_clean['tags'].apply(stem)

# %%
df_clean['tags']
# Out:
# 0       movi kirstenjohnson unitedst documentari pg-13...
# 1       tvshow amaqamata,khosingema,gailmabalane,thaba...
# 2       tvshow julienleclercq samibouajila,tracygotoas...
# 3       tvshow docuseries,realitytv tv-ma feuds, flirt...
# 4       tvshow mayurmore,jitendrakumar,ranjanraj,alamk...
#                               ...
# 8802    movi davidfinch markruffalo,jakegyllenhaal,rob...
# 8803    tvshow kids'tv,koreantvshows,tvcomedi tv-y7 wh...
# 8804    movi rubenfleisch jesseeisenberg,woodyharrelso...
# 8805    movi peterhewitt timallen,courteneycox,chevych...
# 8806    movi mozezsingh vickykaushal,sarah-janedias,ra...
# Name: tags, Length: 8807, dtype: object

# %%
# Performing vectorization to convert the tags into vector values
cv = CountVectorizer(max_features=10000, stop_words='english')
vectorized = cv.fit_transform(df_clean['tags']).toarray()

# %%
vectorized.shape
# Out:
# (8807, 10000)

# %%
# Using cosine similarity to detect the similarity in movies using distance
# Distance and similarity are inveresely proportional
cs = cosine_similarity(vectorized)
cs.shape
# Out:
# (8807, 8807)

# %%
cs[0]
# Out:
# array([1.        , 0.        , 0.16116459, ..., 0.09534626, 0.17407766,
#        0.31980107])

# %%
# Extracting the index of the title in the dataset
df_clean[df_clean['title'] == 'Dick Johnson Is Dead'].index[0]
# Out:
# 0

# %%
# Sorting the values based on the top 5 highest similarity without loosing the index
list(sorted(enumerate(cs[0]), reverse=True, key = lambda x: x[1]))[1:6]
# Out:
# [(2988, 0.4599331055039),
#  (7854, 0.4212117695871159),
#  (1102, 0.41812100500354543),
#  (8693, 0.414578098794425),
#  (8691, 0.41030496993110904)]

# %%
def recommend(movie):
    idx = df_clean[df_clean['title'] == movie].index[0]
    movie_list = list(sorted(enumerate(cs[idx]), reverse=True, key = lambda x: x[1]))[1:6]

    for i in movie_list:
        print(df_clean.iloc[i[0]].title)

# %%
recommend('Zubaan')
# Out:
# Ek Jaan Hain Hum
# The Music of Silence
# Bilu Rakkhosh
# Kaminey
# Once In A Lifetime Sessions with Moby

# %%
pickle.dump(df_clean,open('movies.pkl' ,'wb'))

# %%
df_clean['title'].values
# Out:
# array(['Dick Johnson Is Dead', 'Blood & Water', 'Ganglands', ...,
#        'Zombieland', 'Zoom', 'Zubaan'], dtype=object)

# %%
pickle.dump(cs, open('similarity.pkl', 'wb'))

# %%
df_dict = df_clean.to_dict()
df_dict
# Out:
# {'title': {0: 'Dick Johnson Is Dead',
#   1: 'Blood & Water',
#   2: 'Ganglands',
#   3: 'Jailbirds New Orleans',
#   4: 'Kota Factory',
#   5: 'Midnight Mass',
#   6: 'My Little Pony: A New Generation',
#   7: 'Sankofa',
#   8: 'The Great British Baking Show',
#   9: 'The Starling',
#   10: 'Vendetta: Truth, Lies and The Mafia',
#   11: 'Bangkok Breaking',
#   12: 'Je Suis Karl',
#   13: 'Confessions of an Invisible Girl',
#   14: 'Crime Stories: India Detectives',
#   15: 'Dear White People',
#   16: "Europe's Most Dangerous Man: Otto Skorzeny in Spain",
#   17: 'Falsa identidad',
#   18: 'Intrusion',
#   19: 'Jaguar',
#   20: 'Monsters Inside: The 24 Faces of Billy Milligan',
#   21: 'Resurrection: Ertugrul',
#   22: 'Avvai Shanmughi',
#   23: 'Go! Go! Cory Carson: Chrissy Takes the Wheel',
#   24: 'Jeans',
#   25: 'Love on the Spectrum',
#   26: 'Minsara Kanavu',
#   27: 'Grown Ups',
#   28: 'Dark Skies',
#   29: 'Paranoia',
#   30: 'Ankahi Kahaniya',
#   31: 'Chicago Party Aunt',
#   32: 'Sex Education',
#   33: 'Squid Game',
#   34: 'Tayo and Little Wizards',
#   35: 'The Father Who Moves Mountains',
#   36: 'The Stronghold',
#   37: 'Angry Birds',
#   38: 'Birth of the Dragon',
#   39: 'Chhota Bheem',
#   40: 'He-Man and the Masters of the Universe',
#   41: 'Jaws',
#   42: 'Jaws 2',
#   43: 'Jaws 3',
#   44: 'Jaws: The Revenge',
#   45: 'My Heroes Were Cowboys',
#   46: 'Safe House',
#   47: 'The Smart Money Woman',
#   48: 'Training Day',
#   49: 'Castle and Castle',
#   50: 'Dharmakshetra',
#   51: 'InuYasha the Movie 2: The Castle Beyond the Looking Glass',
#   52: 'InuYasha the Movie 3: Swords of an Honorable Ruler',
#   53: 'InuYasha the Movie 4: Fire on the Mystic Island',
#   54: 'InuYasha the Movie: Affections Touching Across Time',
#   55: 'Nailed It',
#   56: 'Naruto Shippuden the Movie: Blood Prison',
#   57: 'Naruto Shippûden the Movie: Bonds',
#   58: 'Naruto Shippûden the Movie: The Will of Fire',
#   59: 'Naruto Shippuden: The Movie',
#   60: 'Naruto Shippuden: The Movie: The Lost Tower',
#   61: 'Naruto the Movie 2: Legend of the Stone of Gelel',
#   62: 'Naruto the Movie 3: Guardians of the Crescent Moon Kingdom',
#   63: 'Naruto the Movie: Ninja Clash in the Land of Snow',
#   64: 'Nightbooks',
#   65: 'Numberblocks',
#   66: 'Raja Rasoi Aur Anya Kahaniyan',
#   67: 'Saved by the Bell',
#   68: 'Schumacher',
#   69: 'Stories by Rabindranath Tagore',
#   70: 'Too Hot To Handle: Latino',
#   71: 'A StoryBots Space Adventure',
#   72: 'Jack Whitehall: Travels with My Father',
#   73: 'King of Boys',
#   74: "The World's Most Amazing Vacation Rentals",
#   75: 'You vs. Wild: Out Cold',
#   76: 'Yowamushi Pedal',
#   77: 'Little Singham - Black Shadow',
#   78: 'Tughlaq Durbar',
#   79: 'Tughlaq Durbar (Telugu)',
#   80: 'Firedrake the Silver Dragon',
#   81: 'Kate',
#   82: 'Lucifer',
#   83: 'Metal Shop Masters',
#   84: 'Omo Ghetto: the Saga',
#   85: 'Pokémon Master Journeys: The Series',
#   86: 'Prey',
#   87: 'Titipo Titipo',
#   88: 'Blood Brothers: Malcolm X & Muhammad Ali',
#   89: 'Mighty Raju',
#   90: 'Paradise Hills',
#   91: 'The Women and the Murderer',
#   92: 'Into the Night',
#   93: 'JJ+E',
#   94: 'Show Dogs',
#   95: 'The Circle',
#   96: 'If I Leave Here Tomorrow: A Film About Lynyrd Skynyrd',
#   97: 'Kid Cosmic',
#   98: 'Octonauts: Above & Beyond',
#   99: 'On the Verge',
#   100: 'Tobot Galaxy Detectives',
#   101: 'Untold: Breaking Point',
#   102: 'Countdown: Inspiration4 Mission to Space',
#   103: 'Shadow Parties',
#   104: 'Tayo the Little Bus',
#   105: 'Angamaly Diaries',
#   106: "Bunk'd",
#   107: 'A Champion Heart',
#   108: 'Dive Club',
#   109: 'La casa de papel',
#   110: 'Money Heist: From Tokyo to Berlin',
#   111: 'Sharkdog',
#   112: 'Worth',
#   113: 'Afterlife of the Party',
#   114: 'Anjaam',
#   115: 'Bright Star',
#   116: 'Dhanak',
#   117: 'Final Account',
#   118: 'Gurgaon',
#   119: 'Here and There',
#   120: 'Heroes of Goo Jit Zu',
#   121: 'Hotel Del Luna',
#   122: 'In the Cut',
#   123: 'Luv Kushh',
#   124: 'Pororo - The Little Penguin',
#   125: 'Q-Force',
#   126: 'Shikara',
#   127: 'A Cinderella Story',
#   128: "Agatha Christie's Crooked House",
#   129: 'An Unfinished Life',
#   130: 'Barbie Big City Big Dreams',
#   131: 'Blade Runner: The Final Cut',
#   132: 'Brave Animated Series',
#   133: 'Chappie',
#   134: 'Clear and Present Danger',
#   135: 'Cliffhanger',
#   136: 'Cold Mountain',
#   137: 'Crocodile Dundee in Los Angeles',
#   138: 'Dear John',
#   139: 'Do the Right Thing',
#   140: 'El patrón, radiografía de un crimen',
#   141: 'Extraction',
#   142: 'Freedom Writers',
#   143: 'Green Lantern',
#   144: 'House Party',
#   145: 'House Party 2',
#   146: 'House Party 3',
#   147: 'How to Be a Cowboy',
#   148: 'HQ Barbers',
#   149: 'I Got the Hook Up',
#   150: 'In Too Deep',
#   151: 'Initial D',
#   152: 'Janoskians: Untold and Untrue',
#   153: 'Kid-E-Cats',
#   154: "Kuroko's Basketball",
#   155: 'Labyrinth',
#   156: 'Letters to Juliet',
#   157: 'Level 16',
#   158: "Love Don't Cost a Thing",
#   159: 'Love in a Puff',
#   160: 'Major Dad',
#   161: 'Mars Attacks!',
#   162: 'Marshall',
#   163: "My Boss's Daughter",
#   164: 'Mystery Men',
#   165: 'Oldsters',
#   166: 'Once Upon a Time in America',
#   167: 'Open Season 2',
#   168: 'Osmosis Jones',
#   169: 'Poseidon',
#   170: 'Rhyme & Reason',
#   171: 'Same Kind of Different as Me',
#   172: 'School of Rock',
#   173: 'Snervous Tyler Oakley',
#   174: 'Tears of the Sun',
#   175: 'The Blue Lagoon',
#   176: 'The Golden Child',
#   177: 'The Guns of Navarone',
#   178: 'The Interview',
#   179: 'The Nutty Professor',
#   180: 'The Nutty Professor II: The Klumps',
#   181: 'Turning Point: 9/11 and the War on Terror',
#   182: 'Welcome Home Roscoe Jenkins',
#   183: 'In the Line of Fire',
#   184: 'Sparking Joy',
#   185: 'Untold: Crime & Penalties',
#   186: 'Hometown Cha-Cha-Cha',
#   187: 'The Ingenuity of the Househusband',
#   188: '2 Alone in Paris',
#   189: 'Bread Barbershop',
#   190: 'Thimmarusu',
#   191: 'Wind River',
#   192: 'C Kkompany',
#   193: 'D.P.',
#   194: 'Deadly Sins',
#   195: 'EMI: Liya Hai To Chukana Padega',
#   196: "He's All That",
#   197: 'I Heart Arlo',
#   198: 'King of Boys: The Return of the King',
#   199: 'Koi Aap Sa',
#   200: 'Krishna Cottage',
#   201: 'Kucch To Hai',
#   202: 'Kyaa Kool Hai Hum',
#   203: 'Kyaa Kool Hain Hum 3',
#   204: 'Kyaa Super Kool Hain Hum',
#   205: 'Kyo Kii... Main Jhuth Nahin Bolta',
#   206: 'LSD: Love, Sex Aur Dhokha',
#   207: 'Mission Istaanbul: Darr Ke Aagey Jeet Hai',
#   208: 'Once Upon a Time in Mumbaai',
#   209: 'Once Upon a Time in Mumbai Dobaara!',
#   210: 'Ragini MMS',
#   211: 'Ragini MMS 2',
#   212: 'Rebellion',
#   213: 'RIDE ON TIME',
#   214: 'SAS: Rise of the Black Swan',
#   215: 'Shootout at Lokhandwala',
#   216: 'Shor In the City',
#   217: 'The Dirty Picture',
#   218: 'Titletown High',
#   219: 'EDENS ZERO',
#   220: 'Family Reunion',
#   221: 'Bob Ross: Happy Accidents, Betrayal & Greed',
#   222: 'Clickbait',
#   223: 'John of God: The Crimes of a Spiritual Healer',
#   224: 'Motel Makeover',
#   225: 'Open Your Eyes',
#   226: 'Post Mortem: No One Dies in Skarnes',
#   227: 'Really Love',
#   228: 'The November Man',
#   229: 'The Old Ways',
#   230: 'The River Runner',
#   231: 'The Water Man',
#   232: 'Wheel of Fortune',
#   233: 'Count Me In',
#   234: 'Oggy Oggy',
#   235: 'Untold: Caitlyn Jenner',
#   236: 'Boomika',
#   237: 'Boomika (Hindi)',
#   238: 'Boomika (Malayalam)',
#   239: 'Boomika (Telugu)',
#   240: 'The Witcher: Nightmare of the Wolf',
#   241: 'Manifest',
#   242: 'Comedy Premium League',
#   243: 'Everything Will Be Fine',
#   244: 'Gunshot',
#   245: 'Korean Cold Noodle Rhapsody',
#   246: 'Man in Love',
#   247: 'Sweet Girl',
#   248: 'The Chair',
#   249: 'The Loud House Movie',
#   250: 'A Faraway Land',
#   251: 'Like Crazy',
#   252: 'Black Island',
#   253: 'Bombay',
#   254: 'Go! Go! Cory Carson',
#   255: 'Memories of a Murderer: The Nilsen Tapes',
#   256: 'Nneka The Pretty Serpent',
#   257: 'O Kadhal Kanmani',
#   258: 'Out of my league',
#   259: 'Pahuna',
#   260: 'The Defeated',
#   261: 'The Secret Diary of an Exchange Student',
#   262: 'Untold: Deal With the Devil',
#   263: 'Mother Goose Club',
#   264: 'Walk of Shame',
#   265: 'Rascal Does Not Dream of Bunny Girl Senpai',
#   266: 'The Creative Indians',
#   267: 'The Piano',
#   268: 'Unroyal',
#   269: 'Winx Club',
#   270: 'Beckett',
#   271: 'Brand New Cherry Flavor',
#   272: 'Fast & Furious Spy Racers',
#   273: 'Gone for Good',
#   274: 'Grace and Frankie',
#   275: 'The Kingdom',
#   276: 'Valeria',
#   277: 'AlRawabi School for Girls',
#   278: "Lokillo: Nothing's the Same",
#   279: 'Monster Hunter: Legends of the Guild',
#   280: 'Bake Squad',
#   281: 'Brother Jekwu',
#   282: 'La diosa del asfalto',
#   283: 'Misha and the Wolves',
#   284: 'The Kissing Booth 3',
#   285: 'The Railway Man',
#   286: "Gabby's Dollhouse",
#   287: 'I Need Romance',
#   288: 'Las muñecas de la mafia',
#   289: 'The Crowned Clown',
#   290: 'Untold: Malice at the Palace',
#   291: 'SHAMAN KING',
#   292: 'Quartet',
#   293: 'Slay',
#   294: 'Takizawa Kabuki ZERO 2020 The Movie',
#   295: 'The Paper Tigers',
#   296: 'Hit & Run',
#   297: 'Navarasa',
#   298: "Quam's Money",
#   299: 'The Swarm',
#   300: 'Vivo',
#   301: 'Chennai Express',
#   302: 'City of God: 10 Years Later',
#   303: 'Esperando la carroza',
#   304: 'Lady Boss: The Jackie Collins Story',
#   305: 'Tango Feroz',
#   306: "'76",
#   307: 'Aftermath',
#   308: 'American Masters: Inventing David Geffen',
#   309: 'Car Masters: Rust to Riches',
#   310: 'Cocaine Cowboys: The Kings of Miami',
#   311: 'Control Z',
#   312: 'Cooking With Paris',
#   313: "Autumn's Concerto",
#   314: 'Heavy',
#   315: 'Ije: The Journey',
#   316: 'Office Girls',
#   317: 'Pray Away',
#   318: 'Shiny_Flakes: The Teenage Drug Lord',
#   319: 'The Prince Who Turns into a Frog',
#   320: 'Top Secret UFO Projects: Declassified',
#   321: 'Two Fathers',
#   322: "You're My Destiny",
#   323: '30 Rock',
#   324: '44 Cats',
#   325: 'Beethoven',
#   326: "Beethoven's 2nd",
#   327: 'Beowulf',
#   328: 'Boyka: Undisputed',
#   329: 'Catch Me If You Can',
#   330: 'Cloudy with a Chance of Meatballs',
#   331: 'Darwin’s Game',
#   332: 'Deep Blue Sea',
#   333: "Ferris Bueller's Day Off",
#   334: 'Five Feet Apart',
#   335: 'Freedomland',
#   336: 'Friday Night Lights',
#   337: 'Good Luck Chuck',
#   338: 'Hunter X Hunter (2011)',
#   339: "I missed you: Director's Cut",
#   340: 'Inception',
#   341: 'Magnolia',
#   342: 'Major Payne',
#   343: 'My Girl',
#   344: 'My Girl 2',
#   345: 'Open Season: Scared Silly',
#   346: 'Pineapple Express',
#   347: 'Planet 51',
#   348: 'Poms',
#   349: 'Seabiscuit',
#   350: 'Space Cowboys',
#   351: 'Team America: World Police',
#   352: 'The Edge of Seventeen',
#   353: 'The Haunting in Connecticut 2: Ghosts of Georgia',
#   354: 'The Last Boy Scout',
#   355: 'The Lincoln Lawyer',
#   356: 'The Losers',
#   357: 'The Machinist',
#   358: 'The Net',
#   359: 'The Original Kings of Comedy',
#   360: "Valentine's Day",
#   361: 'Charmed',
#   362: 'The Lost Café',
#   363: 'The Vault',
#   364: 'Centaurworld',
#   365: 'Eyes of a Thief',
#   366: 'Glow Up',
#   367: "I'm Glad I Did",
#   368: 'Khawatir',
#   369: 'Myth & Mogul: John DeLorean',
#   370: 'Outer Banks',
#   371: 'Pomegranates and Myrrh',
#   372: 'Rurouni Kenshin: The Beginning',
#   373: 'The Last Mercenary',
#   374: 'Flower Girl',
#   375: 'Resort to Love',
#   376: 'Transformers: War for Cybertron: Kingdom',
#   377: 'Bartkowiak',
#   378: 'Fantastic Fungi',
#   379: 'Tattoo Redo',
#   380: 'The Flash',
#   381: 'The Snitch Cartel: Origins',
#   382: 'All American',
#   383: 'Department',
#   384: 'Hostage House',
#   385: 'How to Sell Drugs Online (Fast)',
#   386: 'Mighty Express',
#   387: 'Mimi',
#   388: 'Plastic Cup Boyz: Laughing My Mask Off!',
#   389: 'The Operative',
#   390: 'The Walking Dead',
#   391: 'Wynonna Earp',
#   392: 'Django Unchained',
#   393: 'A Second Chance:  Rivals!',
#   394: 'African America',
#   395: 'Bankrolled',
#   396: 'Blood Red Sky',
#   397: 'Feels Like Ishq',
#   398: 'Kingdom: Ashin of the North',
#   399: 'Masters of the Universe: Revelation',
#   400: 'Revelations: The Masters of the Universe: Revelation Aftershow',
#   401: 'Sky Rojo',
#   402: 'The Last Letter From Your Lover',
#   403: 'The Movies That Made Us',
#   404: '9to5: The Story of a Movement',
#   405: 'Chhota Bheem - Dinosaur World',
#   406: 'Chhota Bheem - Neeli Pahaadi',
#   407: 'Chhota Bheem & Ganesh',
#   408: 'Chhota Bheem & Krishna: Mayanagari',
#   409: 'Chhota Bheem & Krishna: Pataliputra- City of the Dead',
#   410: 'Chhota Bheem And The Broken Amulet',
#   411: 'Chhota Bheem And The Crown of Valhalla',
#   412: 'Chhota Bheem and the Incan Adventure',
#   413: 'Chhota Bheem and The ShiNobi Secret',
#   414: 'Chhota Bheem Aur Hanuman',
#   415: 'Chhota Bheem aur Krishna',
#   416: 'Chhota Bheem aur Krishna vs Zimbara',
#   417: 'Chhota Bheem in African Safari',
#   418: 'Chhota Bheem Ka Roosi Romanch',
#   419: 'Chhota Bheem: Bheem vs Aliens',
#   420: 'Chhota Bheem: Dholakpur to Kathmandu',
#   421: 'Chhota Bheem: Dus Pe Dus',
#   422: 'Chhota Bheem: Journey to Petra',
#   423: 'Chhota Bheem: Master of Shaolin',
#   424: 'Chhota Bheem: The Rise of Kirmada',
#   425: 'Chicago Med',
#   426: 'Cousins',
#   427: 'Wannabe Courageous',
#   428: 'Words Bubble Up Like Soda Pop',
#   429: 'Sanitation Day',
#   430: 'Sexy Beasts',
#   431: 'Too Hot to Handle: Brazil',
#   432: 'Trollhunters: Rise of the Titans',
#   433: 'Milkwater',
#   434: 'Okupas',
#   435: 'Touch Your Heart',
#   436: 'The Tambour of Retribution',
#   437: 'Cosmic Sin',
#   438: '2 Weeks in Lagos',
#   439: 'Deep',
#   440: 'Explained',
#   441: 'Fear Street Part 3: 1666',
#   442: 'Johnny Test',
#   443: 'La ley de Herodes',
#   444: 'Naomi Osaka',
#   445: 'The Beguiled',
#   446: 'The Book of Henry',
#   447: 'The Twilight Saga: Breaking Dawn: Part 1',
#   448: 'The Twilight Saga: Breaking Dawn: Part 2',
#   449: 'The Twilight Saga: Eclipse',
#   450: 'The Twilight Saga: New Moon',
#   451: 'Twilight',
#   452: 'A Perfect Fit',
#   453: 'BEASTARS',
#   454: "Cheech & Chong's Still Smokin",
#   455: 'Emicida: AmarElo - Live in São Paulo',
#   456: 'Her Private Life',
#   457: 'Lift Like a Girl',
#   458: 'My Amanda',
#   459: 'Never Have I Ever',
#   460: "Surf's Up",
#   461: 'The Unknown Saint',
#   462: 'This Changes Everything',
#   463: 'A Classic Horror Story',
#   464: 'Gunpowder Milkshake',
#   465: 'Heist',
#   466: 'My Unorthodox Life',
#   467: 'Private Network: Who Killed Manuel Buendía?',
#   468: 'The Guide to the Perfect Family',
#   469: 'American Woman',
#   470: 'Bridgerton - The Afterparty',
#   471: 'Day of Destiny',
#   472: 'Ridley Jones',
#   473: 'Born to Play',
#   474: 'American Ultra',
#   475: 'The Stand-Up',
#   476: 'The Tour',
#   477: 'Atypical',
#   478: 'Biohackers',
#   479: 'Fear Street Part 2: 1978',
#   480: 'Finding Hubby',
#   481: 'How I Became a Superhero',
#   482: 'How to Become a Tyrant',
#   483: 'Last Summer',
#   484: 'Lee Su-geun: The Sense Coach',
#   485: 'Lethal Love',
#   486: 'Ratchet and Clank',
#   487: 'The Cook of Castamar',
#   488: 'Virgin River',
#   489: 'Back to Q82',
#   490: 'Elize Matsunaga: Once Upon a Crime',
#   491: 'Home Again',
#   492: 'Midnight Sun',
#   493: 'RESIDENT EVIL: Infinite Darkness',
#   494: 'Rock the Kasbah',
#   495: 'Awon Boyz',
#   496: 'Brick Mansions',
#   497: 'Cat People',
#   498: 'Clash',
#   499: 'Dogs',
#   500: 'Major Grom: Plague Doctor',
#   501: 'Mama Drama',
#   502: 'Tango With Me',
#   503: 'The Mire',
#   504: 'The War Next-door',
#   505: 'Therapy',
#   506: 'This Little Love Of Mine',
#   507: 'Three Thieves',
#   508: 'A Land Imagined',
#   509: 'Ask the StoryBots',
#   510: 'Between',
#   511: 'Chelsea',
#   512: 'Code Lyoko',
#   513: 'Colony',
#   514: 'Cuckoo',
#   515: 'Derry Girls',
#   516: 'Girl from Nowhere',
#   517: 'Good Morning Call',
#   518: 'Har Kisse Ke Hisse: Kaamyaab',
#   519: 'I AM A KILLER',
#   520: 'I Think You Should Leave with Tim Robinson',
#   521: "Kim's Convenience",
#   522: 'Larva',
#   523: 'Marcella',
#   524: 'Midnight Diner: Tokyo Stories',
#   525: 'My Little Pony: Friendship Is Magic',
#   526: 'Orange Is the New Black',
#   527: 'Puffin Rock',
#   528: 'Rehmataan',
#   529: 'Return of the Prodigal Son',
#   530: 'Richie Rich',
#   531: 'Rise: Ini Kalilah',
#   532: 'Scream',
#   533: 'Shtisel',
#   534: 'Si Doel the Movie 2',
#   535: 'Some Assembly Required',
#   536: 'Tales by Light',
#   537: 'Terrace House: Opening New Doors',
#   538: 'The A List',
#   539: 'The New Legends of Monkey',
#   540: 'The Worst Witch',
#   541: 'Truckbhar Swapna',
#   542: 'Ujala',
#   543: 'Undercover',
#   544: "Workin' Moms",
#   545: 'YooHoo to the Rescue',
#   546: 'You Are My Spring',
#   547: 'We the People',
#   548: "Grey's Anatomy",
#   549: 'Big Timber',
#   550: 'Fear Street Part 1: 1994',
#   551: 'Haseen Dillruba',
#   552: 'Holiday on Mars',
#   553: 'Mortel',
#   554: 'RattleSnake - The Ahanna Story',
#   555: 'Snowpiercer',
#   556: 'The 8th Night',
#   557: 'Winchester',
#   558: '6 Bullets',
#   559: 'Air Force One',
#   560: 'Audible',
#   561: 'Austin Powers in Goldmember',
#   562: 'Austin Powers: International Man of Mystery',
#   563: 'Austin Powers: The Spy Who Shagged Me',
#   564: 'Boogie Nights',
#   565: 'Bureau of Magical Things',
#   566: "Charlie's Angels",
#   567: 'Congo',
#   568: 'Dennis the Menace',
#   569: 'Dreamy Eyes',
#   570: 'Dynasty Warriors',
#   571: 'Generation 56k',
#   572: 'Hampstead',
#   573: 'Kung Fu Panda',
#   574: 'Kung Fu Panda 2',
#   575: 'Life as We Know It',
#   576: 'Mary Magdalene',
#   577: 'Masameer County',
#   578: 'Memoirs of a Geisha',
#   579: 'Midnight Run',
#   580: 'Mobile Suit Gundam Hathaway',
#   581: 'Mortal Kombat',
#   582: "Mother's Day",
#   583: 'No Strings Attached',
#   584: 'Not Another Teen Movie',
#   585: 'Ophelia',
#   586: 'Pet Sematary 2',
#   587: 'Quarantine Tales',
#   588: 'Rainbow Rangers',
#   589: 'Red Joan',
#   590: 'Sailor Moon Crystal',
#   591: 'Seven Pounds',
#   592: "She's Out of My League",
#   593: 'Snow Day',
#   594: 'Star Trek',
#   595: 'Stuart Little',
#   596: 'Sword of Trust',
#   597: 'Talladega Nights: The Ballad of Ricky Bobby',
#   598: 'The American',
#   599: 'The Best of Enemies',
#   600: 'The Game',
#   601: 'The Karate Kid',
#   602: 'The Karate Kid Part II',
#   603: 'The Karate Kid Part III',
#   604: 'The Life of David Gale',
#   605: 'The Long Riders',
#   606: 'The Queen',
#   607: 'The Strangers',
#   608: 'The Sum of All Fears',
#   609: 'The Tourist',
#   610: 'Underworld',
#   611: 'Underworld: Awakening',
#   612: 'Underworld: Rise of the Lycans',
#   613: 'Voiceless',
#   614: 'What Dreams May Come',
#   615: 'Why Do Fools Fall in Love',
#   616: 'Working Title',
#   617: 'Young Royals',
#   618: 'America: The Motion Picture',
#   619: 'Deranged',
#   620: "Droppin' Cash: Los Angeles",
#   621: 'Legend\xa0of\xa0Exorcism',
#   622: 'Lying and Stealing',
#   623: 'Mommy Issues',
#   624: 'Prime Time',
#   625: 'Somos.',
#   626: 'Sophie: A Murder in West Cork',
#   627: 'The Daily Life of the Immortal King',
#   628: 'StarBeam',
#   629: 'A Way Back Home',
#   630: 'Killing Them Softly',
#   631: 'The Seven Deadly Sins',
#   632: 'Wanted',
#   633: 'Into the Wind',
#   634: 'Wonder Boy',
#   635: 'Here Comes the Rain',
#   636: 'The Ice Road',
#   637: 'Ray',
#   638: 'Sex/Life',
#   639: 'Godzilla Singular Point',
#   640: 'Jiva!',
#   641: 'Sisters on Track',
#   642: 'The Naked Director',
#   643: 'The Seventh Day',
#   644: 'Good on Paper',
#   645: 'Murder by the Coast',
#   646: 'The House of Flowers: The Movie',
#   647: 'The Parisian Agency: Exclusive Properties',
#   648: 'Too Hot to Handle',
#   649: 'Broken',
#   650: 'O Vendedor de Sonhos',
#   651: 'Osuofia in London',
#   652: 'Osuofia in London II',
#   653: 'This Is Pop',
#   654: '#Selfie',
#   655: '#Selfie 69',
#   656: 'Love Is a Story',
#   657: 'The Mole',
#   658: 'Nevertheless,',
#   659: 'Bangkok Love Stories: Innocence',
#   660: 'Black Lightning',
#   661: 'Call My Agent!',
#   662: 'Champions',
#   663: 'Charité at War',
#   664: 'Cleo & Cuquin',
#   665: 'Deadwind',
#   666: 'Gameboys Level-Up Edition',
#   667: 'Glee',
#   668: 'Hap and Leonard',
#   669: 'Locked Up',
#   670: 'Mobile Suit Gundam II: Soldiers of Sorrow',
#   671: 'Mobile Suit Gundam III: Encounters in Space',
#   672: "Mobile Suit Gundam: Char's Counterattack",
#   673: 'No Time for Shame',
#   674: 'Pose',
#   675: 'REA(L)OVE',
#   676: 'Riverdale',
#   677: "Schitt's Creek",
#   678: 'The Assassination of Gianni Versace',
#   679: 'The Judgement',
#   680: 'The Last Dance',
#   681: "They've Gotta Have Us",
#   682: 'Why Are You Like This',
#   683: 'A Family',
#   684: 'Elite',
#   685: 'Fatherhood',
#   686: 'Hospital Playlist',
#   687: 'Jagame Thandhiram',
#   688: 'Kambili: The Whole 30 Yards',
#   689: 'Mobile Suit Gundam I',
#   690: 'Rurouni Kenshin: The Final',
#   691: 'So Not Worth It',
#   692: 'The Rational Life',
#   693: 'Ali & Ratu Ratu Queens',
#   694: 'Aziza',
#   695: 'Besieged Bread',
#   696: 'Black Summer',
#   697: 'Elite Short Stories: Carla Samuel',
#   698: 'Fan Girl',
#   699: 'Katla',
#   700: 'Record of Ragnarok',
#   701: 'Red Snow',
#   702: 'Silver Linings Playbook',
#   703: 'The Gift',
#   704: 'A Man For The Week End',
#   705: 'Biking Borders',
#   706: 'Elite Short Stories: Omar Ander Alexis',
#   707: "Let's Eat",
#   708: 'Lowriders',
#   709: 'Millennials',
#   710: 'Penguin Town',
#   711: 'Security',
#   712: 'Silver Skates',
#   713: 'Avengers Climate Conundrum',
#   714: 'Beyond Evil',
#   715: 'Elite Short Stories: Nadia Guzmán',
#   716: 'FTA',
#   717: 'Headspace: Unwind Your Mind',
#   718: 'Life of Crime',
#   719: 'Power Rangers Dino Fury',
#   720: 'Rhyme Time Town',
#   721: 'Rogue Warfare: Death of a Nation',
#   722: 'Sir! No Sir!',
#   723: 'The American Bible Challenge',
#   724: 'The Reason I Jump',
#   725: 'Elite Short Stories: Guzmán Caye Rebe',
#   726: 'Metallica: Some Kind of Monster',
#   727: 'Picture a Scientist',
#   728: 'The Devil Below',
#   729: 'Bling Empire - The Afterparty',
#   730: 'Cobra Kai - The Afterparty',
#   731: 'Love (ft. Marriage and Divorce)',
#   732: 'To All the Boys: Always and Forever - The Afterparty',
#   733: 'LEGO Friends: The Power of Friendship',
#   734: 'Lupin',
#   735: 'Sarbath',
#   736: 'Skater Girl',
#   737: 'Trese',
#   738: 'Trese After Dark',
#   739: 'Wish Dragon',
#   740: 'A Haunted House 2',
#   741: 'Blind Intersections',
#   742: 'Camellia Sisters',
#   743: 'Copenhagen',
#   744: 'Locombianos',
#   745: 'Until Midnight',
#   746: 'Awake',
#   747: 'Confusion Na Wa',
#   748: 'Fresh, Fried & Crispy',
#   749: 'L.A.’s Finest',
#   750: 'Tragic Jungle',
#   751: 'Guru Aur Bhole',
#   752: 'Vampire Academy',
#   753: 'Newly Rich, Newly Poor',
#   754: 'A Private War',
#   755: 'Kitty Love: An Homage to Cats',
#   756: 'Small Chops',
#   757: 'Breaking Boundaries: The Science Of Our Planet',
#   758: 'Feel Good',
#   759: 'Fireplace 4K: Classic Crackling Fireplace from Fireplace for Your Home',
#   760: 'Fireplace 4K: Crackling Birchwood from Fireplace for Your Home',
#   761: 'Human: The World Within',
#   762: 'Sweet & Sour',
#   763: 'Sweet Tooth',
#   764: "Trippin' with the Kandasamys",
#   765: 'Xtreme',
#   766: 'Alan Saldaña: Locked Up',
#   767: "Creator's File: GOLD",
#   768: 'Dancing Queens',
#   769: 'From Stress to Happiness',
#   770: 'Myriam Fares: The Journey',
#   771: 'Pretty Guardian Sailor Moon Eternal The Movie',
#   772: 'Summertime',
#   773: 'The Girl and the Gun',
#   774: '2 Hearts',
#   775: 'A Perfect Ending',
#   776: 'American Outlaws',
#   777: 'And Then Came Lola',
#   778: 'Attack on Titan',
#   779: 'Battlefield Earth',
#   780: "Ben & Holly's Little Kingdom",
#   781: 'Black Holes | The Edge of All We Know',
#   782: 'Bliss',
#   783: 'Carnaval',
#   784: 'Cloudburst',
#   785: 'Cocomelon',
#   786: 'Company of Heroes',
#   787: 'Cradle 2 the Grave',
#   788: 'Domestic Disturbance',
#   789: 'Downton Abbey',
#   790: 'Dream/Killer',
#   791: 'Felon',
#   792: 'Flipped',
#   793: 'Fools Rush In',
#   794: 'Gold Statue',
#   795: 'Happy Endings',
#   796: 'Hostel: Part III',
#   797: 'I Am Sam',
#   798: 'Love Jones',
#   799: 'Million Dollar Baby',
#   800: 'Mosquita y Mari',
#   801: 'Never Back Down 2: The Beatdown',
#   802: 'Ninja Assassin',
#   803: 'Ouran High School Host Club',
#   804: 'Population 436',
#   805: 'Racket Boys',
#   806: 'Seven Souls in the Skull Castle: Season Moon Jogen',
#   807: 'Seven Souls in the Skull Castle: Season Moon Kagen',
#   808: 'Sniper: Legacy',
#   809: 'Starsky & Hutch',
#   810: 'Streets of Fire',
#   811: 'Super Monsters: Once Upon a Rhyme',
#   812: 'Swordfish',
#   813: 'The Adventures of Sonic the Hedgehog',
#   814: 'The Four Seasons',
#   815: 'The Girl King',
#   816: 'The Interpreter',
#   817: 'The Meddler',
#   818: 'The Mirror Has Two Faces',
#   819: 'The Outlaw Josey Wales',
#   820: 'The Platform',
#   821: 'The Wedding Guest',
#   822: 'The Wind',
#   823: 'Then Came You',
#   824: 'Welcome Home',
#   825: 'Dirty John',
#   826: 'Bo Burnham: Inside',
#   827: 'One Lagos Night',
#   828: 'Collateral Beauty',
#   829: 'Dog Gone Trouble',
#   830: 'The Kominsky Method',
#   831: 'The Least Expected Day: Inside the Movistar Team 2019',
#   832: 'Word of Honor',
#   833: 'Black Space',
#   834: 'Blue Miracle',
#   835: 'Eden',
#   836: 'Ghost Lab',
#   837: 'Ragnarok',
#   838: 'Soy Rada: Serendipity',
#   839: 'The Day I lost My Shadow',
#   840: 'Baggio: The Divine Ponytail',
#   841: 'Gatao - The Last Stray',
#   842: 'High on the Hog: How African American Cuisine Transformed America',
#   843: "JoJo's Bizarre Adventure",
#   844: 'Nail Bomber: Manhunt',
#   845: 'A Place in the Stars',
#   846: 'Home',
#   847: 'Mad for Each Other',
#   848: 'Master of None',
#   849: 'Sam Smith: Love Goes - Live at Abbey Road Studios',
#   850: '99 Songs',
#   851: '99 Songs (Tamil)',
#   852: '99 Songs (Telugu)',
#   853: 'Army of the Dead',
#   854: 'Creating an Army of the Dead',
#   855: 'Jurassic World Camp Cretaceous',
#   856: 'Strain',
#   857: 'The Neighbor',
#   858: '678',
#   859: 'Asmaa',
#   860: 'Hating Peter Tatchell',
#   861: 'Little Singham Future mein Satakli',
#   862: 'Special',
#   863: 'Spy Kids: All the Time in the World',
#   864: 'Taxi No. 9211',
#   865: 'Sabotage',
#   866: 'Small Town Crime',
#   867: 'The Last Days',
#   868: 'The Magic School Bus',
#   869: 'Who Killed Sara?',
#   870: 'Amy Tan: Unintended Memoir',
#   871: 'Sardar Ka Grandson',
#   872: 'Sleight',
#   873: 'Ahaan',
#   874: 'Booba: Food Puzzle',
#   875: 'Love or Money',
#   876: 'Alma Matters',
#   877: 'Cinema Bandi',
#   878: 'Ferry',
#   879: 'Halston',
#   880: 'Haunted',
#   881: 'I Am All Girls',
#   882: 'Jungle Beat: The Movie',
#   883: 'Love, Death & Robots',
#   884: 'Move to Heaven',
#   885: 'Table Manners',
#   886: 'The Mystic River',
#   887: 'The Strange House',
#   888: 'The Upshaws - The Afterparty',
#   889: 'The Woman in the Window',
#   890: 'Castlevania',
#   891: 'Layer Cake',
#   892: 'Tottaa Pataaka Item Maal',
#   893: 'Wave of Cinema: Filosofi Kopi',
#   894: 'Dance of the Forty One',
#   895: 'Oxygen',
#   896: 'The Upshaws',
#   897: 'Use For My Talent',
#   898: 'Dear Affy',
#   899: 'Illegal Woman',
#   900: 'Money, Explained',
#   901: 'Deadly Switch',
#   902: 'Mine',
#   903: 'Nayattu',
#   904: 'Sleepless',
#   905: 'Super Me',
#   906: 'Have You Ever Seen Fireflies? - Theatre Play',
#   907: "In Our Mothers' Gardens",
#   908: "Jupiter's Legacy",
#   909: 'Milestone',
#   910: 'Monster',
#   911: 'Sab Jholmaal Hai',
#   912: 'The Circle - The Afterparty',
#   913: 'Time to Dance',
#   914: 'Unrest',
#   915: 'And Tomorrow the Entire World',
#   916: 'Dead Man Down',
#   917: 'Framing John DeLorean',
#   918: 'Lava Ka Dhaava',
#   919: 'The Sons of Sam: A Descent into Darkness',
#   920: 'Selena: The Series',
#   921: 'StartUp',
#   922: 'The Clovehitch Killer',
#   923: 'Trash Truck',
#   924: 'Aliens Stole My Body',
#   925: 'Angelina Ballerina',
#   926: 'Au coeur des gangs',
#   927: 'Barney and Friends',
#   928: 'Best of the Best',
#   929: 'Dead Again in Tombstone',
#   930: 'Due Date',
#   931: 'Fun with Dick & Jane',
#   932: 'Green Zone',
#   933: "Hachi: A Dog's Tale",
#   934: 'JT LeRoy',
#   935: "Madagascar 3: Europe's Most Wanted",
#   936: 'Miniforce: Super Dino Power',
#   937: "Motu Patlu in Dragon's World",
#   938: 'Motu Patlu in the Game of Zones',
#   939: 'Motu Patlu in Wonderland',
#   940: 'Motu Patlu: Deep Sea Adventure',
#   941: 'Motu Patlu: Mission Moon',
#   942: 'Mystic River',
#   943: 'Never Back Down',
#   944: 'S.M.A.R.T Chase',
#   945: 'Sitting in Limbo',
#   946: 'Stargate',
#   947: 'State of Play',
#   948: 'Swiped',
#   949: 'The Darkest Hour',
#   950: 'The Lovely Bones',
#   951: 'The Sweetest Thing',
#   952: 'The Whole Nine Yards',
#   953: 'The Whole Truth',
#   954: 'The Yeti Adventures',
#   955: 'Under Siege',
#   956: 'Zack and Miri Make a Porno',
#   957: 'Pet Stars',
#   958: 'Seven',
#   959: 'The Disciple',
#   960: 'The Innocent',
#   961: 'The Mitchells vs. The Machines',
#   962: 'The Strangers: Prey at Night',
#   963: 'The Unremarkable Juanquini',
#   964: 'Things Heard & Seen',
#   965: 'Yasuke',
#   966: 'Get the Grift',
#   967: 'Headspace Guide to Sleep',
#   968: 'Sexify',
#   969: 'August: Osage County',
#   970: 'Battle: Los Angeles',
#   971: 'Between Worlds',
#   972: 'Fatma',
#   973: 'One',
#   974: 'Ram Prasad Ki Tehrvi',
#   975: 'Shadow and Bone - The Afterparty',
#   976: 'Among Family',
#   977: 'Dedemin Fisi',
#   978: 'Deliha',
#   979: 'Düğün Dernek',
#   980: 'Dügün Dernek 2: Sünnet',
#   981: 'G.O.R.A',
#   982: 'Hayat Öpücügü',
#   983: 'Heroes: Silence and Rock & Roll',
#   984: 'Kara Bela',
#   985: 'Kocan Kadar Konus',
#   986: 'Kocan Kadar Konus 2: Dirilis',
#   987: 'Legal Hash',
#   988: "Let's Fight Ghost",
#   989: 'My Travel Buddy',
#   990: 'Niyazi Gül Dörtnala',
#   991: 'One Like It',
#   992: 'Perfume Imaginary Museum “Time Warp”',
#   993: 'Shadow and Bone',
#   994: 'This Lady Called Life',
#   995: 'Vizontele',
#   996: 'HOMUNCULUS',
#   997: 'Life in Color with David Attenborough',
#   998: 'Searching For Sheela',
#   999: 'Stowaway',
#   ...},
#  'tags': {0: 'movi kirstenjohnson unitedst documentari pg-13 as her father near the end of hi life, filmmak kirsten johnson stage hi death in invent and comic way to help them both face the inevitable.',
#   1: 'tvshow amaqamata,khosingema,gailmabalane,thabangmolaba,dillonwindvogel,natashathahane,arnogreeff,xoliletshabalala,getmoresithole,cindymahlangu,ryledemorny,gretelifincham,sellomaakeka-ncube,odwagwanya,mekailamathys,sandischultz,duanewilliams,shamillamiller,patrickmofokeng southafrica internationaltvshows,tvdramas,tvmysteri tv-ma after cross path at a party, a cape town teen set out to prove whether a private-school swim star is her sister who wa abduct at birth.',
#   2: 'tvshow julienleclercq samibouajila,tracygotoas,samueljouy,nabihaakkari,sofialesaffre,salimkechiouche,noureddinefarihi,geertvanrampelberg,bakarydiombera crimetvshows,internationaltvshows,tvaction&adventur tv-ma to protect hi famili from a power drug lord, skill thief mehdi and hi expert team of robber are pull into a violent and deadli turf war.',
#   3: 'tvshow docuseries,realitytv tv-ma feuds, flirtat and toilet talk go down among the incarcer women at the orlean justic center in new orlean on thi gritti realiti series.',
#   4: 'tvshow mayurmore,jitendrakumar,ranjanraj,alamkhan,ahsaaschanna,revathipillai,urvisingh,arunkumar india internationaltvshows,romantictvshows,tvcomedi tv-ma in a citi of coach center known to train india’ finest collegi minds, an earnest but unexcept student and hi friend navig campu life.',
#   988: 'tvshow kongkiatkhomsiri suppapongudomkaewkanjana,patchananjiajirachote,thongpoomsiripipat,apiwitreardon,kornrawichsungkitbool,waratthayawongchayaporn,wannasaksirilar thailand internationaltvshows,romantictvshows,tvcomedi tv-14 a med student with a supernatur gift tri to cash in on hi abil by face off against ghosts, till a wander spirit bring romanc instead.',
#   989: "movi bedrangüzel oğuzhankoç,i̇brahimbüyükak,emrekınay,aslıbekiroğlu,edaece,baharşahin,muharrembayrak,toyganavanoğlu turkey comedies,internationalmovi tv-ma day befor eid, a salesman fire from hi job drive to ayvalık to meet hi girlfriend' family, but the trip goe astray due to hi zani travel buddy.",
#   990: "movi hakanalgül atademirer,demetakbağ,şebnembozoklu,leventülgen turkey comedies,internationalmovi tv-ma seek the formula behind a magic elixir bequeath to him by hi father, a veterinari professor get embroil in a mobster' horse-rac scheme.",
#   991: 'movi marwannabil rihamabdelghafour,mohammedalyrizk,hazemsamir,salwaothman,mahmoudgharib egypt dramas,independentmovies,internationalmovi tv-g thi short film follow a day in the life of a young woman in egypt and how her interact with other expos long-stand stereotyp and biases.',
#   992: 'movi mikiko,daitomanab perfum internationalmovies,music&mus tv-g thi visual stun special perform wa the highlight of perfume’ "p.o.p" festiv — the j-pop trio’ 20th anniversari onlin celebration.',
#   993: 'tvshow jessiemeili,archierenaux,benbarnes,freddycarter,amitasuman,kityoung,daniellegalligan,calahanskogman,sujayadasgupta,simonsears,daisyhead,zoëwanamaker,lukepasqualino,juliankostov unitedst tvaction&adventure,tvdramas,tvsci-fi&fantasi tv-14 dark forc conspir against orphan mapmak alina starkov when she unleash an extraordinari power that could chang the fate of her war-torn world.',
#   994: "movi kayodekasum bisolaaiyeola,efaiwara,molawaonajobi,tinamba,waleojo,jemimaosunde,lotachukwu,samuelasa'ah,michaelejoor,ucheelumelu nigeria dramas,internationalmovies,romanticmovi tv-14 abandon by her family, young singl mother aiy struggl to surviv but stay focus on her dream of becom an elit chef.",
#   995: "movi yılmazerdoğan,ömerfaruksorak yılmazerdoğan,demetakbağ,altanerkekli,cemyılmaz,cezmibaskın,bicangünalan,sebnemsönmez,i̇clalaydın,mesutçakarli,zeyneptokuş turkey comedies,dramas,internationalmovi tv-ma in 1974, a rural town in anatolia get it first televis set – an event that' met with both excit and trepid by the villagers.",
#   996: "movi takashishimizu goayano,ryonarita,yukinokishii,annaishii,seiyouchino japan horrormovies,internationalmovies,thril tv-ma truth and illus blur when a homeless amnesiac awaken from an experiment medic procedur with the abil to see people' innermost traumas.",
#   997: 'tvshow davidattenborough australia,unitedkingdom britishtvshows,docuseries,internationaltvshow tv-pg use innov technology, thi docuseri explor natur from a fresh perspect as anim use color to surviv and thrive in the wild.',
#   998: 'movi maanandsheela india documentaries,internationalmovi tv-14 journalist and fan await ma anand sheela as the infam former rajneesh commune’ spokesperson return to india after decad for an interview tour.',
#   999: 'movi joepenna annakendrick,tonicollette,danieldaekim,shamieranderson germany,unitedst dramas,internationalmovies,thril tv-ma a three-person crew on a mission to mar face an imposs choic when an unplan passeng jeopard the live of everyon on board.',
#   ...}}

# %%
pickle.dump(df_dict,open('movies_dict.pkl' ,'wb'))
